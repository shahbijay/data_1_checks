# %% [markdown]
# # Import libraries.

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Data File

# %%
housing_data = pd.read_csv('Boston_Housing_Data.csv')
housing_data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# # Display graph using above data.

# %% [markdown]
# ## Scatter Plot

# %%
fig = plt.gcf()

# Change seaborn plot size
fig.set_size_inches(12, 6)

# Create a scatter plot using seaborn
sns.scatterplot(x='CRIM', y='MEDV', data=housing_data)

# Set plot title and labels
plt.title('Crime Rate vs Median Home Value Scatter Plot')
plt.xlabel('Crime Rate')
plt.ylabel('Median Home Value')

# Display the plot
plt.show()

# %% [markdown]
# ## Heat Map

# %%
# Create a heatmap using seaborn
sns.heatmap(housing_data[['CRIM', 'MEDV']].corr(), annot=True, cmap='coolwarm')

# Set plot title
plt.title('Crime Rate vs Median Home Value Heat Map')

# Display the plot
plt.show()

# %% [markdown]
# ## Box Plot

# %%
# Create a box plot using seaborn
sns.boxplot(data=housing_data[['CRIM', 'MEDV']], palette='Set3')

# Set plot title and labels
plt.title('Crime Rate vs Median Home Value Box Plot')
plt.xlabel('Variable')
plt.ylabel('Value')

# Display the plot
plt.show()

# %%
import urllib
from urllib.request import urlretrieve

url = 'http://lib.stat.cmu.edu/datasets/boston'
urlretrieve(url, 'boston.txt')

df_web = pd.read_table('boston.txt', header=None, skiprows=22, delim_whitespace=True, names=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV'])
print(df_web.shape)
df_web.head()
# Out:
# (1012, 14)
#         CRIM     ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.00   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  396.90000   4.98  24.00   NaN    NaN    NaN   NaN     NaN  NaN    NaN
# 2    0.02731   0.00   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 3  396.90000   9.14  21.60   NaN    NaN    NaN   NaN     NaN  NaN    NaN
# 4    0.02729   0.00   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
#
#    PTRATIO   B  LSTAT  MEDV
# 0     15.3 NaN    NaN   NaN
# 1      NaN NaN    NaN   NaN
# 2     17.8 NaN    NaN   NaN
# 3      NaN NaN    NaN   NaN
# 4     17.8 NaN    NaN   NaN

# %%
import pandas as pd

url = 'http://lib.stat.cmu.edu/datasets/boston'
df = pd.read_csv(url, skiprows=22, delim_whitespace=True, header=None)

data = []
row = []
for i, val in enumerate(df.values.flatten()):
    row.append(val)
    if len(row) == 14:
        data.append(row)
        row = []

df_clean = pd.DataFrame(data, columns=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV'])
print(df_clean.shape)
print(df_clean.head())
# Out:
# (795, 14)
#        CRIM       ZN    INDUS   CHAS     NOX       RM     AGE     DIS  \
# 0   0.00632  18.0000  2.31000    0.0   0.538    6.575  65.200   4.090
# 1       NaN      NaN      NaN    NaN     NaN      NaN     NaN     NaN
# 2  78.90000   4.9671  2.00000  242.0  17.800  396.900   9.140  21.600
# 3       NaN      NaN  0.02729    0.0   7.070    0.000   0.469   7.185
# 4   4.03000  34.7000      NaN    NaN     NaN      NaN     NaN     NaN
#
#         RAD       TAX   PTRATIO      B   LSTAT     MEDV
# 0   1.00000  296.0000  15.30000  396.9   4.980   24.000
# 1   0.02731    0.0000   7.07000    0.0   0.469    6.421
# 2       NaN       NaN       NaN    NaN     NaN      NaN
# 3  61.10000    4.9671   2.00000  242.0  17.800  392.830
# 4       NaN       NaN   0.03237    0.0   2.180    0.000

# %% [markdown]
# # First read all the data from URL

# %%
import urllib
from urllib.request import urlretrieve
import pandas as pd

url = 'http://lib.stat.cmu.edu/datasets/boston'
urlretrieve(url, 'boston.txt')

data = []
with open('boston.txt', 'r') as file:
    for line in file:
        row = line.split()
        if len(data) == 0:
            data.append(row[:14])
        elif len(data[-1]) < 14:
            data[-1].extend(row[:14-len(data[-1])])
        else:
            data.append(row[:14])

df_web = pd.DataFrame(data, columns=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV'])
print(df_web.shape)
df_web.head(25)
# Out:
# (515, 14)
#        CRIM          ZN         INDUS         CHAS       NOX         RM  \
# 0       The      Boston   house-price         data        of  Harrison,
# 1    vol.5,     81-102,         1978.         Used        in   Belsley,
# 2     pages     244-261            of          the   latter.  Variables
# 3        ZN  proportion            of  residential      land      zoned
# 4      CHAS     Charles         River        dummy  variable         (=
# 5        RM     average        number           of     rooms        per
# 6       DIS    weighted     distances           to      five     Boston
# 7       TAX  full-value  property-tax         rate       per    $10,000
# 8     LSTAT           %         lower       status        of        the
# 9   0.00632       18.00         2.310            0    0.5380     6.5750
# 10  0.02731        0.00         7.070            0    0.4690     6.4210
# 11  0.02729        0.00         7.070            0    0.4690     7.1850
# ...

# %% [markdown]
# ## Since the above dataframe has 9 rows that is not data, let's delete those rows and create a new dataframe called "boston_housing"

# %%
# Create a new DataFrame with rows 9 to the end of table-1
boston_housing = df_web.iloc[9:, :].reset_index(drop=True)

# Print the shape of the new DataFrame
boston_housing
# Out:
#         CRIM     ZN   INDUS CHAS     NOX      RM    AGE     DIS RAD    TAX  \
# 0    0.00632  18.00   2.310    0  0.5380  6.5750  65.20  4.0900   1  296.0
# 1    0.02731   0.00   7.070    0  0.4690  6.4210  78.90  4.9671   2  242.0
# 2    0.02729   0.00   7.070    0  0.4690  7.1850  61.10  4.9671   2  242.0
# 3    0.03237   0.00   2.180    0  0.4580  6.9980  45.80  6.0622   3  222.0
# 4    0.06905   0.00   2.180    0  0.4580  7.1470  54.20  6.0622   3  222.0
# ..       ...    ...     ...  ...     ...     ...    ...     ...  ..    ...
# 501  0.06263   0.00  11.930    0  0.5730  6.5930  69.10  2.4786   1  273.0
# 502  0.04527   0.00  11.930    0  0.5730  6.1200  76.70  2.2875   1  273.0
# 503  0.06076   0.00  11.930    0  0.5730  6.9760  91.00  2.1675   1  273.0
# 504  0.10959   0.00  11.930    0  0.5730  6.7940  89.30  2.3889   1  273.0
# 505  0.04741   0.00  11.930    0  0.5730  6.0300  80.80  2.5050   1  273.0
#
#     PTRATIO       B LSTAT   MEDV
# 0     15.30  396.90  4.98  24.00
# ...
