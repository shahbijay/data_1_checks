# %%
api.openweathermap.org/data/2.5/forecast/daily?lat={lat}&lon={lon}&cnt={cnt}&appid={API key}

# %%
# First import required libraries.

import requests
import pandas as pd

# %%
import requests

# Set the API endpoint URL
url = "https://api.census.gov/data/timeseries/healthins/sahie"

# Set the parameters for the API request
params = {
    "get": "NIC_PT,NUI_PT",
    "for": "county:*",
    "in": "state:10",
    "time": "2020"
}

# Send the GET request to the API endpoint
response = requests.get(url, params=params)

# Retrieve the JSON response
data = response.json()

# Process the data as needed
# ...

# %%
data
# Out:
# [['NIC_PT', 'NUI_PT', 'time', 'state', 'county'],
#  ['133287', '12220', '2020', '10', '001'],
#  ['418070', '31367', '2020', '10', '003'],
#  ['153165', '13930', '2020', '10', '005']]

# %%
import requests

# Set the API endpoint URL
url = "https://api.census.gov/data/timeseries/healthins/sahie"

# Set the parameters for the API request
params = {
    "get": "NIC_PT,NUI_PT",
    "for": "county:*",
    "in": "state:12",
    "time": "2020"
}

# Send the GET request to the API endpoint
response = requests.get(url, params=params)

# Retrieve the JSON response
data = response.json()

# Process the data as needed
# ...
data
# Out:
# [['NIC_PT', 'NUI_PT', 'time', 'state', 'county'],
#  ['191174', '24881', '2020', '12', '001'],
#  ['19516', '2901', '2020', '12', '003'],
#  ['113256', '22500', '2020', '12', '005'],
#  ['16332', '2653', '2020', '12', '007'],
#  ['392350', '62742', '2020', '12', '009'],
#  ['1319355', '265926', '2020', '12', '011'],
#  ['8148', '1564', '2020', '12', '013'],
#  ['93391', '18950', '2020', '12', '015'],
#  ['79992', '14253', '2020', '12', '017'],
#  ['159321', '24628', '2020', '12', '019'],
#  ['212198', '46388', '2020', '12', '021'],
#  ['44817', '7616', '2020', '12', '023'],
#  ['19458', '6624', '2020', '12', '027'],
#  ['9286', '1617', '2020', '12', '029'],
#  ['691221', '104240', '2020', '12', '031'],
#  ['211901', '34716', '2020', '12', '033'],
#  ['68186', '11745', '2020', '12', '035'],
#  ['6013', '1351', '2020', '12', '037'],
#  ['26743', '5691', '2020', '12', '039'],
#  ['11496', '2199', '2020', '12', '041'],
#  ['6212', '2276', '2020', '12', '043'],
#  ['8147', '1443', '2020', '12', '045'],
#  ['7435', '1397', '2020', '12', '047'],
#  ['16318', '3999', '2020', '12', '049'],
#  ['25560', '9764', '2020', '12', '051'],
#  ['119118', '22251', '2020', '12', '053'],
#  ['53190', '12344', '2020', '12', '055'],
#  ['1092445', '159595', '2020', '12', '057'],
#  ['11414', '2314', '2020', '12', '059'],
#  ['86631', '18225', '2020', '12', '061'],
#  ['25626', '4297', '2020', '12', '063'],
#  ['8077', '1498', '2020', '12', '065'],
#  ['4597', '1030', '2020', '12', '067'],
#  ['227125', '41915', '2020', '12', '069'],
#  ['442140', '105507', '2020', '12', '071'],
#  ['210443', '25410', '2020', '12', '073'],
#  ['24878', '5655', '2020', '12', '075'],
#  ['4142', '812', '2020', '12', '077'],
#  ['10324', '2047', '2020', '12', '079'],
#  ['244340', '45368', '2020', '12', '081'],
#  ['211410', '40007', '2020', '12', '083'],
#  ['91636', '15547', '2020', '12', '085'],
#  ['1798090', '384832', '2020', '12', '086'],
#  ['45848', '9679', '2020', '12', '087'],
#  ['61230', '8771', '2020', '12', '089'],
#  ['147927', '25259', '2020', '12', '091'],
#  ['23772', '6471', '2020', '12', '093'],
#  ['1015211', '175979', '2020', '12', '095'],
#  ['276859', '47762', '2020', '12', '097'],
#  ['909288', '201215', '2020', '12', '099'],
#  ['378979', '57567', '2020', '12', '101'],
#  ['617043', '98540', '2020', '12', '103'],
#  ['478607', '91500', '2020', '12', '105'],
#  ['44657', '9489', '2020', '12', '107'],
#  ['200277', '22407', '2020', '12', '109'],
#  ['201973', '44555', '2020', '12', '111'],
#  ['131303', '21986', '2020', '12', '113'],
#  ['230133', '43253', '2020', '12', '115'],
#  ['348930', '48712', '2020', '12', '117'],
#  ['43170', '5820', '2020', '12', '119'],
#  ['26573', '5453', '2020', '12', '121'],
#  ['12207', '2140', '2020', '12', '123'],
#  ['7305', '845', '2020', '12', '125'],
#  ['343547', '61020', '2020', '12', '127'],
#  ['21871', '3546', '2020', '12', '129'],
#  ['49173', '9906', '2020', '12', '131'],
#  ['14693', '3672', '2020', '12', '133']]
